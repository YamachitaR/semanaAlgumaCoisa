# %% [markdown]
# # Introdução
#
# Estamos baseado no projeto **President Heights**  do site [The Clever Programmer](https://thecleverprogrammer.com/2020/05/08/data-science-project-on-president-heights/) do autor **Aman Kharwal**

# %%
# Importando as bibliotecas
import pandas as pd
import numpy as np

# %%
# carregando os dados 
df = pd.read_csv('datasets/president_heights.csv')
df
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %% [markdown]
# ## Uma pequena Analise Estatistica

# %%
df['height(cm)'].describe()
# Out:
# count     42.000000
# mean     179.738095
# std        7.015869
# min      163.000000
# 25%      174.250000
# 50%      182.000000
# 75%      183.000000
# max      193.000000
# Name: height(cm), dtype: float64

# %% [markdown]
# ## Analise gráfico

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

plt.hist(df['height(cm)'])
plt.title("Height Distribution of Presidents of USA")
plt.xlabel("height(cm)")
plt.ylabel("Number")
plt.show()

# %%
plt.scatter(x=df['order'],  y= df['height(cm)'])
plt.show()
